# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from warnings import filterwarnings
filterwarnings('ignore')

# %%
umich = pd.read_csv('../data/umich.csv',index_col=0)
umich = umich[umich['Run'] != 'R16']

# %%
def rolling_avg(run_df,window_size=300):
    list_of_pressure_names = ['p1','p2','p3','p4','p5']
    for px in list_of_pressure_names:
        run_df[px+'rol_avg'] = run_df[px].rolling(window_size).mean()
    for px in list_of_pressure_names:
        run_df[px+'rol_med'] = run_df[px].rolling(window_size).median()
    #for px in list_of_pressure_names:
        #run_df[px+'rol_var'] = run_df[px].rolling(window_size).var()
    #for px in list_of_pressure_names:
        #run_df[px+'rol_var'] = run_df[px].rolling(window_size).std()
        
    run_df = run_df.fillna(0)
    return run_df

# %%
runs = umich['Run'].unique()
variables = {}

# Loop through a range of values
for i in runs:
    # Create a new variable name
    variable_name = f"{i}"
    
    # Create a new variable value
    variable_value = umich[umich['Run']==i]
    
    # Assign the variable value to the variable name in the dictionary
    variables[variable_name] = variable_value.reset_index(drop=True)

for variable_name, variable_value in variables.items():
    globals()[variable_name] = variable_value
    
df_list = [R0, R1, R2, R3, R4, R5, R6, R7, R8, R9, R10, R11,
           R12, R13, R14, R15, R17, R18, R19, R20, R21,
           R22, R23, R24, R25, R26, R27, R28, R29, R30, R31,
           R32, R33, R34, R35, R36, R37] # Note: R16 is dropped because of NaN values.

pressure_transducers = ['p1','p2','p3','p4','p5']
location_list = ['px1','px2','px3','px4','px5']

# %%
train_run = ['R0','R8','R2','R12','R32','R24','R36']

test_run = ['R28','R29','R30','R31','R37','R21','R6','R9','R10',
             'R11','R23','R33','R35','R24','R27','R13','R14','R15','R20',
            'R1','R3','R4','R5','R7','R17','R18','R19','R22','R25','R26']

train_set = umich[umich['Run'].isin(train_run)]
test_set = umich[umich['Run'].isin(test_run)]

# %%
# Generates a dataframe with rolling averages & mean
variables = {}
for i in train_run:
    # Create a new variable name
    variable_name = f"train_{i}"
    
    # Create a new variable value
    variable_value = train_set[train_set['Run']==i]
    
    # Assign the variable value to the variable name in the dictionary
    variables[variable_name] = variable_value.reset_index(drop=True)

for variable_name, variable_value in variables.items():
    globals()[variable_name] = variable_value
    
df_list = [R0, R1, R2, R3, R4, R5, R6, R7, R8, R9, R10, R11,
           R12, R13, R14, R15, R17, R18, R19, R20, R21,
           R22, R23, R24, R25, R26, R27, R28, R29, R30, R31,
           R32, R33, R34, R35, R36, R37] # Note: R16 is dropped because of NaN values.

# %%
list_of_rolled_df_train = []
list_of_rolled_df_test = []

for i in train_run:
    list_of_rolled_df_train.append(rolling_avg(umich[umich['Run']==i]))
for i in test_run:
    list_of_rolled_df_test.append(rolling_avg(umich[umich['Run']==i]))

# %%
full_rolled_train = pd.concat(list_of_rolled_df_train)
full_rolled_test = pd.concat(list_of_rolled_df_test)

# %%
full_rolled_train = full_rolled_train[full_rolled_train['time']>=0.0300]
full_rolled_test = full_rolled_test[full_rolled_test['time']>=0.0300]

# %% [markdown]
# # UMICH Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler

# %%
def RunNeuralNet(train_df, test_df):
    X_train = train_df.drop(['x1','time','Run','H','W'],axis=1)
    X_test = test_df.drop(['x1','time','Run','H','W'],axis=1)
    y_train = train_df['x1']
    y_test = test_df['x1']

    ss = StandardScaler()

    X_train_scaled = ss.fit_transform(X_train)
    X_test_scaled = ss.transform(X_test)
    
    model = Sequential()

    model.add(Dense(20, activation='relu'))
    model.add(Dense(30, activation='relu'))
    model.add(Dense(1))

    model.compile(optimizer='adam',loss='mse')
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, mode='min', verbose=1)
    
    model.fit(x=X_train_scaled,y=y_train.values,
          validation_data=(X_test_scaled,y_test.values),
          batch_size=128,epochs=100,callbacks=[early_stopping])
    
    y_pred = model.predict(X_test_scaled)
    test_df = test_df.copy()
    test_df['pred'] = y_pred
    
    return test_df,model

# %%
test_df,model = RunNeuralNet(full_rolled_train, full_rolled_test)
# Out:
# Epoch 1/100
# 1686/1686 [==============================] - 3s 1ms/step - loss: 71558.4141 - val_loss: 1394.0651
# Epoch 2/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 521.8706 - val_loss: 449.6395
# Epoch 3/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 157.1781 - val_loss: 273.8268
# Epoch 4/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 97.1623 - val_loss: 181.0482
# Epoch 5/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 67.0939 - val_loss: 126.5648
# Epoch 6/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 50.6237 - val_loss: 95.8275
# Epoch 7/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 41.9181 - val_loss: 77.5513
# Epoch 8/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 36.5715 - val_loss: 65.7727
# Epoch 9/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 31.9944 - val_loss: 54.7910
# Epoch 10/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 28.3777 - val_loss: 47.5568
# Epoch 11/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 25.8824 - val_loss: 44.3197
# Epoch 12/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 24.1243 - val_loss: 42.0445
# Epoch 13/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 22.8423 - val_loss: 38.7324
# Epoch 14/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 21.8679 - val_loss: 37.6717
# Epoch 15/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 21.0229 - val_loss: 35.9627
# Epoch 16/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 20.3883 - val_loss: 35.7059
# Epoch 17/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 19.7596 - val_loss: 34.2682
# Epoch 18/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 19.2030 - val_loss: 33.5471
# Epoch 19/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 18.6677 - val_loss: 32.9461
# Epoch 20/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 18.3963 - val_loss: 32.8617
# Epoch 21/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 18.0121 - val_loss: 32.8483
# Epoch 22/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 17.7610 - val_loss: 32.2456
# Epoch 23/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 17.4601 - val_loss: 32.9047
# Epoch 24/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 17.2128 - val_loss: 31.6989
# Epoch 25/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 16.9552 - val_loss: 31.4911
# Epoch 26/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 16.6817 - val_loss: 30.9254
# Epoch 27/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 16.4848 - val_loss: 31.5952
# Epoch 28/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 16.2896 - val_loss: 30.1715
# Epoch 29/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 16.0767 - val_loss: 30.6947
# Epoch 30/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 15.9847 - val_loss: 30.5330
# Epoch 31/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 15.8890 - val_loss: 30.3430
# Epoch 32/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 15.8177 - val_loss: 30.8725
# Epoch 33/100
# 1686/1686 [==============================] - 2s 1ms/step - loss: 15.6790 - val_loss: 30.8508
# Epoch 33: early stopping
# 28897/28897 [==============================] - 6s 212us/step

# %%
model.save("model_significant")
# Out:
# INFO:tensorflow:Assets written to: model_significant/assets
# INFO:tensorflow:Assets written to: model_significant/assets

# %% [markdown]
# # Transfer Learning Method (AFIT)

# %%
afit = pd.read_csv('../data/afit.csv',index_col=0)

# %%
R6 = afit[afit['Run']=='R6']
R7 = afit[afit['Run']=='R7']
R8 = afit[afit['Run']=='R8']

run_list = [R6,R7,R8]

# %%
train = R8.drop(['time','Run'],axis=1)
test = pd.concat([R6,R7])
test = test.drop(['time','Run'],axis=1)

# %%
X_train = train.drop('x1',axis=1)
y_train = train['x1']
X_test = test.drop('x1',axis=1)
y_test = test['x1']

# %%
#from random import sample

#index = sample([i for i in range(31)],25)

#X_train = X_train.iloc[:,index]
#X_test = X_test.iloc[:,index]

# %%
train[['px2', 'px9', 'px3', 'p8', 'H', 'p7', 'W', 'px7', 'p1', 'px4', 'px6',
       'px5', 'px10', 'p2', 'px13', 'px12', 'L', 'p14', 'px8', 'p12']]
# Out:
#        px2    px9   px3        p8    H        p7    W   px7        p1   px4  \
# 3665  2.57  10.88  3.76  5.236325  2.5  5.436452  2.5  8.51  4.594629  4.94
# 3666  2.57  10.88  3.76  5.344038  2.5  5.343885  2.5  8.51  4.540004  4.94
# 3668  2.57  10.88  3.76  5.248293  2.5  5.413310  2.5  8.51  4.528222  4.94
# 3669  2.57  10.88  3.76  5.248293  2.5  5.390168  2.5  8.51  4.551786  4.94
# 3670  2.57  10.88  3.76  5.272229  2.5  5.413310  2.5  8.51  4.550715  4.94
# ...    ...    ...   ...       ...  ...       ...  ...   ...       ...   ...
# 9675  2.57  10.88  3.76  5.367974  2.5  5.274460  2.5  8.51  4.544288  4.94
# 9676  2.57  10.88  3.76  5.248293  2.5  5.297602  2.5  8.51  4.564639  4.94
# 9677  2.57  10.88  3.76  5.427814  2.5  5.459593  2.5  8.51  4.552857  4.94
# 9678  2.57  10.88  3.76  5.248293  2.5  5.413310  2.5  8.51  4.500374  4.94
# 9679  2.57  10.88  3.76  5.332070  2.5  5.390168  2.5  8.51  4.573207  4.94
#
#        px6   px5   px10        p2   px13   px12     L        p14  px8  \
# 3665  7.32  6.13  12.07  5.004554  18.01  15.64  5.05   9.348691  9.7
# 3666  7.32  6.13  12.07  5.107406  18.01  15.64  5.05   9.104833  9.7
# 3668  7.32  6.13  12.07  4.922504  18.01  15.64  5.05   9.359854  9.7
# 3669  7.32  6.13  12.07  5.053091  18.01  15.64  5.05   9.109126  9.7
# 3670  7.32  6.13  12.07  5.062336  18.01  15.64  5.05   9.288585  9.7
# ...    ...   ...    ...       ...    ...    ...   ...        ...  ...
# 9675  7.32  6.13  12.07  4.968730  18.01  15.64  5.05  11.175057  9.7
# 9676  7.32  6.13  12.07  4.912103  18.01  15.64  5.05  11.190512  9.7
# 9677  7.32  6.13  12.07  5.002243  18.01  15.64  5.05  11.278954  9.7
# 9678  7.32  6.13  12.07  4.973352  18.01  15.64  5.05  11.143286  9.7
# 9679  7.32  6.13  12.07  5.042691  18.01  15.64  5.05  11.212838  9.7
#
#            p12
# 3665  5.855930
# 3666  5.749688
# 3668  5.827807
# 3669  5.827807
# 3670  5.640322
# ...        ...
# 9675  5.745001
# 9676  5.710629
# 9677  5.568452
# 9678  6.041853
# 9679  5.671569
       'px5', 'px10', 'p2', 'px13', 'px12', 'L', 'p14', 'px8', 'p12']]

X_test = test[['px2', 'px9', 'px3', 'p8', 'H', 'p7', 'W', 'px7', 'p1', 'px4', 'px6',
      'px5', 'px10', 'p2', 'px13', 'px12', 'L', 'p14', 'px8', 'p12']]

# %%
from tensorflow.keras.models import load_model

# %%
base_model = load_model('model.h5')

# %%
new_model = Sequential()

base_model.trainable=False

new_model.add(base_model)
new_model.add(Dense(20, activation='relu'))

new_model.add(Dense(1))
              
new_model.compile(optimizer='adam',loss='mse')

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, mode='min', verbose=1)

# %%
result = new_model.fit(x=X_train.values,y=y_train.values,
          validation_data=(X_test.values,y_test.values),
          batch_size=100,epochs=200,callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 61/61 [==============================] - 0s 2ms/step - loss: 1479.3549 - val_loss: 18.0572
# Epoch 2/200
# 61/61 [==============================] - 0s 980us/step - loss: 6.8070 - val_loss: 0.3585
# Epoch 3/200
# 61/61 [==============================] - 0s 979us/step - loss: 0.3974 - val_loss: 0.2709
# Epoch 4/200
# 61/61 [==============================] - 0s 963us/step - loss: 0.3894 - val_loss: 0.2732
# Epoch 5/200
# 61/61 [==============================] - 0s 947us/step - loss: 0.3893 - val_loss: 0.2713
# Epoch 6/200
# 61/61 [==============================] - 0s 950us/step - loss: 0.3890 - val_loss: 0.2770
# Epoch 7/200
# 61/61 [==============================] - 0s 941us/step - loss: 0.3892 - val_loss: 0.2765
# Epoch 8/200
# 61/61 [==============================] - 0s 955us/step - loss: 0.3896 - val_loss: 0.2730
# Epoch 9/200
# 61/61 [==============================] - 0s 968us/step - loss: 0.3891 - val_loss: 0.2762
# Epoch 10/200
# 61/61 [==============================] - 0s 1ms/step - loss: 0.3891 - val_loss: 0.2762
# Epoch 11/200
# 61/61 [==============================] - 0s 983us/step - loss: 0.3892 - val_loss: 0.2756
# Epoch 12/200
# 61/61 [==============================] - 0s 959us/step - loss: 0.3894 - val_loss: 0.2732
# Epoch 13/200
# 61/61 [==============================] - 0s 931us/step - loss: 0.3890 - val_loss: 0.2737
# Epoch 14/200
# 61/61 [==============================] - 0s 937us/step - loss: 0.3893 - val_loss: 0.2749
# Epoch 15/200
# 61/61 [==============================] - 0s 1ms/step - loss: 0.3891 - val_loss: 0.2757
# Epoch 16/200
# 61/61 [==============================] - 0s 1ms/step - loss: 0.3895 - val_loss: 0.2757
# Epoch 17/200
# 61/61 [==============================] - 0s 1ms/step - loss: 0.3893 - val_loss: 0.2738
# Epoch 18/200
# 61/61 [==============================] - 0s 994us/step - loss: 0.3890 - val_loss: 0.2704
# Epoch 19/200
# 61/61 [==============================] - 0s 989us/step - loss: 0.3890 - val_loss: 0.2721
# Epoch 20/200
# 61/61 [==============================] - 0s 992us/step - loss: 0.3894 - val_loss: 0.2787
# Epoch 21/200
# 61/61 [==============================] - 0s 985us/step - loss: 0.3890 - val_loss: 0.2756
# Epoch 22/200
# 61/61 [==============================] - 0s 971us/step - loss: 0.3892 - val_loss: 0.2756
# Epoch 23/200
# 61/61 [==============================] - 0s 1ms/step - loss: 0.3890 - val_loss: 0.2774
# Epoch 24/200
# 61/61 [==============================] - 0s 1ms/step - loss: 0.3885 - val_loss: 0.2812
# Epoch 25/200
# 61/61 [==============================] - 0s 1ms/step - loss: 0.3889 - val_loss: 0.2750
# Epoch 26/200
# 61/61 [==============================] - 0s 987us/step - loss: 0.3888 - val_loss: 0.2754
# Epoch 27/200
# 61/61 [==============================] - 0s 1ms/step - loss: 0.
# 61/61 [==============================] - 0s 967us/step - loss: 0.3865 - val_loss: 0.2795
# Epoch 60/200
# 61/61 [==============================] - 0s 968us/step - loss: 0.3861 - val_loss: 0.2761
# Epoch 61/200
# 61/61 [==============================] - 0s 973us/step - loss: 0.3861 - val_loss: 0.2746
# Epoch 62/200
# 61/61 [==============================] - 0s 989us/step - loss: 0.3862 - val_loss: 0.2981
# Epoch 63/200
# 61/61 [==============================] - 0s 986us/step - loss: 0.3889 - val_loss: 0.2739
# Epoch 64/200
# 61/61 [==============================] - 0s 985us/step - loss: 0.3856 - val_loss: 0.2989
# Epoch 65/200
# 61/61 [==============================] - 0s 988us/step - loss: 0.3871 - val_loss: 0.2976
# Epoch 66/200
# 61/61 [==============================] - 0s 968us/step - loss: 0.3855 - val_loss: 0.2877
# Epoch 67/200
# 61/61 [==============================] - 0s 1ms/step - loss: 0.3852 - val_loss: 0.2862
# Epoch 68/200
# 61/61 [==============================] - 0s 1ms/step - loss: 0.3848 - val_loss: 0.3012
# Epoch 69/200
# 61/61 [==============================] - 0s 988us/step - loss: 0.3865 - val_loss: 0.2993
# Epoch 69: early stopping

# %%
pd.DataFrame(result.history).plot()
# Out:
# <Axes: >

# %%
y_pred = new_model.predict(X_test)
# Out:
# 409/409 [==============================] - 0s 241us/step

# %%
test_full = afit[(afit['Run']=='R6') | (afit['Run']=='R7')]

# %%
test_full['pred'] = y_pred

# %%
plt.figure(figsize=(15,5))

plt.plot(test_full[test_full['Run']=='R6']['time'],test_full[test_full['Run']=='R6']['x1'], label='True STLE')
plt.plot(test_full[test_full['Run']=='R6']['time'],test_full[test_full['Run']=='R6']['pred'],label='Predicted STLE',alpha=0.8)

for j in ['px1', 'px2', 'px3', 'px4', 'px5', 'px6', 'px7', 'px8', 'px9', 'px10',
          'px11', 'px12', 'px13', 'px14']:
    plt.axhline(test_full[j].iloc[0],color='red',alpha=.3)
    
plt.show()

# %%
plt.figure(figsize=(15,5))

plt.plot(test_full[test_full['Run']=='R7']['time'],test_full[test_full['Run']=='R7']['x1'], label='True STLE')
plt.plot(test_full[test_full['Run']=='R7']['time'],test_full[test_full['Run']=='R7']['pred'],label='Predicted STLE',alpha=0.8)

for j in ['px1', 'px2', 'px3', 'px4', 'px5', 'px6', 'px7', 'px8', 'px9', 'px10',
          'px11', 'px12', 'px13', 'px14']:
    plt.axhline(test_full[j].iloc[0],color='red',alpha=.3)
    
plt.show()

# %%
X_train.columns
# Out:
# Index(['px2', 'px9', 'px3', 'p8', 'H', 'p7', 'W', 'px7', 'p1', 'px4', 'px6',
#        'px5', 'px10', 'p2', 'px13', 'px12', 'L', 'p14', 'px8', 'p12'],
#       dtype='object')

# %% [markdown]
# - ['px9', 'p8', 'px13', 'p13', 'p3', 'L', 'px8', 'p5', 'p6', 'p12', 'p11',
#        'px2', 'H', 'px6', 'p4', 'p10', 'px3', 'p14', 'p7', 'px10']
# - ['px2', 'px9', 'px3', 'p8', 'H', 'p7', 'W', 'px7', 'p1', 'px4', 'px6',
#        'px5', 'px10', 'p2', 'px13', 'px12', 'L', 'p14', 'px8', 'p12'] (REALLY GOOD)
